# %% [markdown]
# <table style="text-align: center;">
#    <img src="tracking-basics.png"/>
# </tr>

# %% [markdown]
# <table style="text-align: center;">
#    <img src="autologging-intro.png"/>
# </tr>

# %%
import mlflow

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
from sklearn.ensemble import RandomForestRegressor

mlflow.autolog()

db = load_diabetes()
X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)

# Create and train models.
rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)
rf.fit(X_train, y_train)

# Use the model to make predictions on the test dataset.
predictions = rf.predict(X_test)
# Out:
# 2025/11/02 18:15:32 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2025/11/02 18:15:32 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b81c58bb4f26476a8c54762764b3cf1e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow

# %%
# !mlflow ui --port=5001
# Out:
# [MLflow] Security middleware enabled with default settings (localhost-only). To allow connections from other hosts, use --host 0.0.0.0 and configure --allowed-hosts and --cors-allowed-origins.
# INFO:     Uvicorn running on http://127.0.0.1:5001 (Press CTRL+C to quit)
# INFO:     Started parent process [7692]
# INFO:     Started server process [7695]
# INFO:     Waiting for application startup.
# INFO:     Started server process [7697]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Application startup complete.
# INFO:     Started server process [7696]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Started server process [7694]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# ^C
#
# Aborted!
# INFO:     Shutting down
# INFO:     Shutting down
# INFO:     Shutting down
# INFO:     Shutting down
# INFO:     Received SIGINT, exiting.
# INFO:     Received SIGINT, exiting.
# INFO:     Terminated child process [7694]
# INFO:     Terminated child process [7695]
# INFO:     Terminated child process [7696]
# INFO:     Terminated child process [7697]
# INFO:     Waiting for child process [7694]
# INFO:     Finished server process [7695]
# INFO:     Finished server process [7696]
# INFO:     Finished server process [7697]
# INFO:     Finished server process [7694]
# INFO:     Waiting for child process [7695]
# INFO:     Waiting for child process [7696]
# INFO:     Waiting for child process [7697]
# INFO:     Stopping parent process [7692]

# %%
import mlflow 
from sklearn.model_selection import train_test_split 
from sklearn.datasets import load_diabetes

# set the experiment id
mlflow.set_experiment(experiment_id="0")

mlflow.autolog() 
db = load_diabetes() 

X_train, X_test, y_train, y_test = train_test_split(db.data, db.target) 

# Create and train models. 
rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3) 
rf.fit(X_train, y_train) 

# Use the model to make predictions on the test dataset. 
predictions = rf.predict(X_test)
# Out:
# 2025/11/02 18:16:00 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2025/11/02 18:16:00 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '7370536597ce47cbafbc9ea1d0ed0ef4', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow

# %%
# !mlflow ui --port=5001
# Out:
# [MLflow] Security middleware enabled with default settings (localhost-only). To allow connections from other hosts, use --host 0.0.0.0 and configure --allowed-hosts and --cors-allowed-origins.
# INFO:     Uvicorn running on http://127.0.0.1:5001 (Press CTRL+C to quit)
# INFO:     Started parent process [91725]
# INFO:     Started server process [91729]
# INFO:     Waiting for application startup.
# INFO:     Started server process [91728]
# INFO:     Waiting for application startup.
# INFO:     Started server process [91727]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Started server process [91730]
# INFO:     Application startup complete.
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Application startup complete.
# INFO:     127.0.0.1:53426 - "GET / HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:53427 - "GET /ajax-api/2.0/mlflow/traces?experiment_ids=0&order_by=timestamp_ms%20DESC&max_results=1&filter= HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53434 - "GET /ajax-api/2.0/mlflow/experiments/get?experiment_id=0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53435 - "POST /ajax-api/2.0/mlflow/experiments/search-datasets HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53429 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53429 - "GET /ajax-api/2.0/mlflow/gateway-proxy?gateway_path=api%2F2.0%2Fendpoints%2F HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53431 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53435 - "POST /ajax-api/2.0/mlflow/logged-models/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53426 - "POST /graphql HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53440 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=run_id%3D%277370536597ce47cbafbc9ea1d0ed0ef4%27 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53439 - "POST /graphql HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53439 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%257370536597ce47cbafbc9ea1d0ed0ef4%25%22 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53440 - "POST /ajax-api/2.0/mlflow/logged-models/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53443 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%257370536597ce47cbafbc9ea1d0ed0ef4%25%22 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53443 - "GET /ajax-api/2.0/mlflow/artifacts/list?run_uuid=7370536597ce47cbafbc9ea1d0ed0ef4 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53443 - "GET /static-files/static/media/fontawesome-webfont.20fd1704ea223900efa9.woff2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53443 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%257370536597ce47cbafbc9ea1d0ed0ef4%25%22 HTTP/1.1" 200 OK
# ^C
# INFO:     Shutting down
# INFO:     Shutting down
#
# Aborted!
# INFO:     Shutting down
# INFO:     Finished server process [91727]
# INFO:     Finished server process [91728]
# INFO:     Finished server process [91729]
# ERROR:    Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/runners.py", line 204, in run
#     return runner.run(main)
#            ~~~~~~~~~~^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/runners.py", line 127, in run
#     return self._loop.run_until_complete(task)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/base_events.py", line 706, in run_until_complete
#     self.run_forever()
#     ~~~~~~~~~~~~~~~~^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/base_events.py", line 677, in run_forever
#     self._run_once()
#     ~~~~~~~~~~~~~~^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/base_events.py", line 2046, in _run_once
#     handle._run()
#     ~~~~~~~~~~~^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/events.py", line 94, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/site-packages/uvicorn/server.py", line 70, in serve
#     with self.capture_signals():
#          ~~~~~~~~~~~~~~~~~~~~^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/contextlib.py", line 148, in __exit__
#     next(self.gen)
#     ~~~~^^^^^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/site-packages/uvicorn/server.py", line 331, in capture_signals
#     signal.raise_signal(captured_signal)
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/runners.py", line 166, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/site-packages/starlette/routing.py", line 700, in lifespan
#     await receive()
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/site-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/queues.py", line 186, in get
#     await getter
# asyncio.exceptions.CancelledError
#
# ERROR:    Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/runners.py", line 204, in run
#     return runner.run(main)
#            ~~~~~~~~~~^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/runners.py", line 127, in run
#     return self._loop.run_until_complete(task)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/base_events.py", line 706, in run_until_complete
#     self.run_forever()
#     ~~~~~~~~~~~~~~~~^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/base_events.py", line 677, in run_forever
#     self._run_once()
#     ~~~~~~~~~~~~~~^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/base_events.py", line 2046, in _run_once
#     handle._run()
#     ~~~~~~~~~~~^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/events.py", line 94, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/site-packages/uvicorn/server.py", line 70, in serve
#     with self.capture_signals():
#          ~~~~~~~~~~~~~~~~~~~~^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/contextlib.py", line 148, in __exit__
#     next(self.gen)
#     ~~~~^^^^^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/site-packages/uvicorn/server.py", line 331, in capture_signals
#     signal.raise_signal(captured_signal)
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/runners.py", line 166, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/site-packages/starlette/routing.py", line 700, in lifespan
#     await receive()
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/site-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/queues.py", line 186, in get
#     await getter
# asyncio.exceptions.CancelledError
#
# ERROR:    Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/runners.py", line 204, in run
#     return runner.run(main)
#            ~~~~~~~~~~^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/runners.py", line 127, in run
#     return self._loop.run_until_complete(task)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/base_events.py", line 706, in run_until_complete
#     self.run_forever()
#     ~~~~~~~~~~~~~~~~^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/base_events.py", line 677, in run_forever
#     self._run_once()
#     ~~~~~~~~~~~~~~^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/base_events.py", line 2046, in _run_once
#     handle._run()
#     ~~~~~~~~~~~^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/events.py", line 94, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/site-packages/uvicorn/server.py", line 70, in serve
#     with self.capture_signals():
#          ~~~~~~~~~~~~~~~~~~~~^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/contextlib.py", line 148, in __exit__
#     next(self.gen)
#     ~~~~^^^^^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/site-packages/uvicorn/server.py", line 331, in capture_signals
#     signal.raise_signal(captured_signal)
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/runners.py", line 166, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/site-packages/starlette/routing.py", line 700, in lifespan
#     await receive()
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/site-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/queues.py", line 186, in get
#     await getter
# asyncio.exceptions.CancelledError
#
# INFO:     Finished server process [91730]
# ERROR:    Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/runners.py", line 204, in run
#     return runner.run(main)
#            ~~~~~~~~~~^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/runners.py", line 127, in run
#     return self._loop.run_until_complete(task)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/base_events.py", line 706, in run_until_complete
#     self.run_forever()
#     ~~~~~~~~~~~~~~~~^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/base_events.py", line 677, in run_forever
#     self._run_once()
#     ~~~~~~~~~~~~~~^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/base_events.py", line 2046, in _run_once
#     handle._run()
#     ~~~~~~~~~~~^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/events.py", line 94, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/site-packages/uvicorn/server.py", line 70, in serve
#     with self.capture_signals():
#          ~~~~~~~~~~~~~~~~~~~~^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/contextlib.py", line 148, in __exit__
#     next(self.gen)
#     ~~~~^^^^^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/site-packages/uvicorn/server.py", line 331, in capture_signals
#     signal.raise_signal(captured_signal)
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/runners.py", line 166, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/site-packages/starlette/routing.py", line 700, in lifespan
#     await receive()
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/site-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/mlopslab/lib/python3.14/asyncio/queues.py", line 186, in get
#     await getter
# asyncio.exceptions.CancelledError

# %% [markdown]
# ### Store ML models

# %%
import mlflow
from mlflow.models import infer_signature

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
from sklearn.ensemble import RandomForestRegressor

with mlflow.start_run() as run:
    # Load the diabetes dataset.
    db = load_diabetes()
    X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)

    # Create and train models.
    rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)
    rf.fit(X_train, y_train)

    # Use the model to make predictions on the test dataset.
    predictions = rf.predict(X_test)
    print(predictions)

    signature = infer_signature(X_test, predictions)
    mlflow.sklearn.log_model(rf, "model", signature=signature)

    print(f"Run ID: {run.info.run_id}")
# Out:
# 2025/11/02 18:16:26 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [159.93954549 205.93366081 213.05885871  94.26064225  83.74034575
#  167.52243847 164.28718012 245.08451937 111.9515061  185.39793717
#  149.36538325 179.83663485 115.50499399 187.66135838  92.14192814
#  103.6834244  169.17411873 112.81458283 227.04922152 108.88215875
#  201.81330745  99.93882353 169.09343408 176.42095154 101.5180422
#  242.03876378 177.97648384 106.99155718  93.03216929  98.62953268
#  191.22847156  91.3835301  128.83704256  87.27061596 218.8464096
#  242.26831254 102.77920726 183.3253842  147.04704264 218.74639196
#  198.76701027 181.6986371  214.03959781 230.52127067 154.89000054
#  201.10414694 134.75288587 135.02625751 133.1415532  159.81507296
#   92.61713063 224.37271497 225.91250717 114.48205241 199.07644458
#  199.33243639 118.92603004 227.18199547  86.21268456 129.51247862
#  253.3631773  207.81916195 122.20659134  97.85764602 125.08698594
#  201.49638314  91.38935213 207.05971957 186.98798453 168.28856244
#  124.90002944 161.74868072 226.62601804 186.88862919 117.65609106
#  188.98205127  85.03291697 104.00472374 139.51010155 105.65553924
#  177.18985791 161.72514968 197.89991725 143.83803619  96.31147889
#   91.75290029 102.25081526 182.34271021 154.84359682 147.31992254
#   92.33130926 150.90571199 173.08363976  91.22809892 143.63964267
#  177.30299073 130.34510835 113.23753222 254.831182   148.57665515
#  245.50671648 164.68670326 227.65289311 217.98638692 230.78470545
#  229.24611987 167.52693702 218.29280225 118.91424579 198.85976418
#  152.55951197]
# Run ID: 3fcb78b386b4473da75337df8567e3ca

# %%
# !mlflow ui --port=5001
# Out:
# [MLflow] Security middleware enabled with default settings (localhost-only). To allow connections from other hosts, use --host 0.0.0.0 and configure --allowed-hosts and --cors-allowed-origins.
# INFO:     Uvicorn running on http://127.0.0.1:5001 (Press CTRL+C to quit)
# INFO:     Started parent process [92229]
# INFO:     Started server process [92232]
# INFO:     Waiting for application startup.
# INFO:     Started server process [92234]
# INFO:     Started server process [92231]
# INFO:     Waiting for application startup.
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Application startup complete.
# INFO:     Application startup complete.
# INFO:     Started server process [92233]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     127.0.0.1:53530 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53540 - "GET / HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:53542 - "GET /ajax-api/2.0/mlflow/traces?experiment_ids=0&order_by=timestamp_ms%20DESC&max_results=1&filter= HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53544 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53542 - "GET /ajax-api/2.0/mlflow/experiments/get?experiment_id=0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53546 - "POST /ajax-api/2.0/mlflow/experiments/search-datasets HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53542 - "GET /ajax-api/2.0/mlflow/gateway-proxy?gateway_path=api%2F2.0%2Fendpoints%2F HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53540 - "POST /graphql HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53544 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53546 - "POST /ajax-api/2.0/mlflow/logged-models/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53552 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=run_id%3D%273fcb78b386b4473da75337df8567e3ca%27 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53551 - "POST /graphql HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53551 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%253fcb78b386b4473da75337df8567e3ca%25%22 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53552 - "POST /ajax-api/2.0/mlflow/logged-models/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53552 - "GET / HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:53557 - "POST /graphql HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53555 - "GET /ajax-api/2.0/mlflow/logged-models/m-73975e84897b49c8a5671c932a9598bd HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53555 - "GET /ajax-api/2.0/mlflow/registered-models/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53555 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3fcb78b386b4473da75337df8567e3ca HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53555 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%253fcb78b386b4473da75337df8567e3ca%25%22 HTTP/1.1" 200 OK
# ^C
#
# Aborted!
# INFO:     Received SIGINT, exiting.
# INFO:     Received SIGINT, exiting.
# INFO:     Terminated child process [92231]
# INFO:     Terminated child process [92232]
# INFO:     Terminated child process [92233]
# INFO:     Terminated child process [92234]
# INFO:     Waiting for child process [92231]
# INFO:     Shutting down
# INFO:     Shutting down
# INFO:     Shutting down
# INFO:     Shutting down
# INFO:     Finished server process [92233]
# INFO:     Finished server process [92231]
# INFO:     Finished server process [92234]
# INFO:     Finished server process [92232]
# INFO:     Waiting for child process [92232]
# INFO:     Waiting for child process [92233]
# INFO:     Waiting for child process [92234]
# INFO:     Stopping parent process [92229]

# %% [markdown]
# ### Load a model

# %%
import mlflow

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes

db = load_diabetes()
X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)

model = mlflow.sklearn.load_model("mlruns/0/a7edd2653458481ab60488297d06a781/artifacts/model/")
predictions = model.predict(X_test)
print(predictions)
